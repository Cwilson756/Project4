# %%
import pandas as pd

# %%
# Read CSV into Pandas DataFrame
file_path = 'Starting_Data/Project4_StartingData_noMeta.csv'
df = pd.read_csv(file_path)
df
# Out:
#       occurrence_no record_type  reid_no flags  collection_no  \
# 0            139242         occ  24752.0   NaN          11890
# 1            139250         occ  23301.0   NaN          11893
# 2            139252         occ  23302.0   NaN          11895
# 3            139253         occ  18699.0   NaN          11896
# 4            139254         occ  13634.0   NaN          11897
# ...             ...         ...      ...   ...            ...
# 4795        1626150         occ      NaN   NaN         230164
# 4796        1626151         occ      NaN   NaN         230165
# 4797        1626154         occ      NaN   NaN         230166
# 4798        1626155         occ      NaN   NaN          97806
# 4799        1626277         occ      NaN   NaN          14455
#
#                           identified_name identified_rank  identified_no  \
# 0           Gorgosaurus n. sp. sternbergi         species          63900
# 1                    Gorgosaurus libratus         species          53194
# 2                    Gorgosaurus libratus         species          53194
# 3                    Gorgosaurus libratus         species          53194
# 4     n. gen. Gorgosaurus n. sp. libratus         species          53194
# ...                                   ...             ...            ...
# 4795                Ankylosauridae indet.          family          38831
# 4796                Ankylosauridae indet.          family          38831
# 4797     Ankylosauridae indet. A informal          family          38831
# 4798     Ankylosauridae indet. B informal          family          38831
# 4799    Dromaeosauridae indet. B informal          family          38561
#
#                  difference         accepted_name  ...   stratgroup  \
# 0     subjective synonym of  Gorgosaurus libratus  ...  Belly River
# 1                       NaN  Gorgosaurus libratus  ...  Belly River
# 2                       NaN  Gorgosaurus libratus  ...  Belly River
# 3                       NaN  Gorgosaurus libratus  ...  Belly River
# 4                       NaN  Gorgosaurus libratus  ...  Belly River
# ...                     ...                   ...  ...          ...
# 4795                    NaN        Ankylosauridae  ...          NaN
# 4796                    NaN        Ankylosauridae  ...          NaN
# 4797    obsolete variant of        Ankylosauridae  ...          NaN
# 4798    obsolete variant of        Ankylosauridae  ...          NaN
# 4799    obsolete variant of       Dromaeosauridae  ...      Matawan
#
#                  member                                       lithdescript  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                          "sandstone, plant matter"
# 3                   NaN                                                NaN
# 4                   NaN                           "tough clayey sandstone"
# ...                 ...                                                ...
# 4795     Reynolds Point                                                NaN
# 4796     Reynolds Point                                                NaN
# 4797  Last Chance Creek                                                NaN
# 4798                NaN                                   "silty mudstone"
# 4799                NaN  "normally not lithified... coarser sandy layer...
#
#         lithology1  lithification1  minor_lithology1  lithology2  \
# 0        sandstone             NaN               NaN         NaN
# 1        sandstone             NaN               NaN         NaN
# 2        sandstone             NaN      carbonaceous         NaN
# 3     not reported             NaN               NaN         NaN
# 4        sandstone       lithified      argillaceous         NaN
# ...            ...             ...               ...         ...
# 4795  not reported             NaN               NaN         NaN
# 4796  not reported             NaN               NaN         NaN
# 4797  not reported             NaN               NaN         NaN
# 4798      mudstone             NaN             silty         NaN
# 4799     sandstone     unlithified               NaN         NaN
#
#      lithification2  minor_lithology2         environment
# 0               NaN               NaN           "channel"
# 1               NaN               NaN           "channel"
# 2               NaN               NaN         channel lag
# 3               NaN               NaN  terrestrial indet.
# 4               NaN               NaN         channel lag
# ...             ...               ...                 ...
# 4795            NaN               NaN      fluvial indet.
# 4796            NaN               NaN  terrestrial indet.
# 4797            NaN               NaN  terrestrial indet.
# 4798            NaN               NaN  terrestrial indet.
# 4799            NaN               NaN         estuary/bay
#
# [4800 rows x 31 columns]

# %%
value_counts = df['genus'].value_counts()
value_counts_df = pd.DataFrame(value_counts)
value_counts_updated_df = value_counts_df.drop(value_counts_df[value_counts_df.genus < 50].index)
value_counts_updated_df.head(11)
##print(len(value_counts_updated_df))
# Out:
#                    genus
# Richardoestesia      145
# Saurornitholestes    132
# Grallator            132
# Eubrontes            102
# Phalacrocorax         94
# Allosaurus            89
# Troodon               86
# Paronychodon          86
# Tyrannosaurus         67
# Anas                  64
# Stegosaurus           53
