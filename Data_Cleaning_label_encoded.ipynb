# %%
import pandas as pd
import re

# %%
# Read CSV into Pandas DataFrame
file_path = 'Starting_Data/Project4_StartingData_noMeta.csv'
df = pd.read_csv(file_path)
df
# Out:
#       occurrence_no record_type  reid_no flags  collection_no  \
# 0            139242         occ  24752.0   NaN          11890
# 1            139250         occ  23301.0   NaN          11893
# 2            139252         occ  23302.0   NaN          11895
# 3            139253         occ  18699.0   NaN          11896
# 4            139254         occ  13634.0   NaN          11897
# ...             ...         ...      ...   ...            ...
# 4795        1626150         occ      NaN   NaN         230164
# 4796        1626151         occ      NaN   NaN         230165
# 4797        1626154         occ      NaN   NaN         230166
# 4798        1626155         occ      NaN   NaN          97806
# 4799        1626277         occ      NaN   NaN          14455
#
#                           identified_name identified_rank  identified_no  \
# 0           Gorgosaurus n. sp. sternbergi         species          63900
# ...

# %%
# Check Genus Value Counts
value_counts = df['genus'].value_counts()
value_counts_df = pd.DataFrame(value_counts)
value_counts_updated_df = value_counts_df.drop(value_counts_df[value_counts_df.genus < 50].index)
value_counts_updated_df.head(11)
# Out:
#                    genus
# Richardoestesia      145
# Saurornitholestes    132
# Grallator            132
# Eubrontes            102
# Phalacrocorax         94
# Allosaurus            89
# Troodon               86
# Paronychodon          86
# Tyrannosaurus         67
# Anas                  64
# Stegosaurus           53

# %%
# Remove Quotes Function
def remove_quotes(value):
    if isinstance(value, str):
        return value.strip('"')
    return value

# %%
# Create Clean DataFrame with desired columns
column_df = df[['max_ma', 'min_ma', 'genus', 'lng', 'lat', 'lithology1', 'environment']]
clean_df = column_df.applymap(remove_quotes)

# %%
# Fill NA values in the lithology1 column with 'not reported' to match other data
clean_df['lithology1'] = clean_df['lithology1'].fillna('not reported')

# %%
# Check value counts of the lithology1 column
clean_value_counts = clean_df['lithology1'].value_counts()
print(clean_value_counts)
# Out:
# sandstone                        2162
# not reported                     1211
# mudstone                          294
# siliciclastic                     285
# claystone                         202
# siltstone                         201
# limestone                         142
# shale                             114
# conglomerate                       77
# tar                                27
# marl                               20
# lime mudstone                      14
# diatomite                           8
# carbonate                           7
# chalk                               7
# wackestone                          6
# grainstone                          4
# tuff                                4
# coal                                3
# amber                               2
# packstone                           2
# ash                                 2
# lignite                             1
# dolomite                            1
# ironstone                           1
# ...

# %%
# Drop any remaining NA values, run the remove quotes function, and view the DataFrame
clean_df = clean_df.dropna(how='any')
clean_df
# Out:
#       max_ma  min_ma            genus         lng        lat    lithology1  \
# 0       83.5    70.6      Gorgosaurus -111.528732  50.740726     sandstone
# 1       83.5    70.6      Gorgosaurus -111.549347  50.737015     sandstone
# 2       83.5    70.6      Gorgosaurus -111.564636  50.723866     sandstone
# 3       83.5    70.6      Gorgosaurus -111.525337  50.740471  not reported
# 4       83.5    70.6      Gorgosaurus -111.601021  50.786999     sandstone
# ...      ...     ...              ...         ...        ...           ...
# 4780   237.0   201.3        Grallator -109.569000  38.602001  not reported
# 4781    83.5    70.6    Panoplosaurus -111.564636  50.723866  not reported
# 4783    83.5    70.6  Richardoestesia -108.320999  36.507999  not reported
# 4788    83.5    70.6  Richardoestesia -108.320602  36.508499     sandstone
# 4790    83.5    70.6    Tyrannosaurus -108.320999  36.507999  not reported
#
#              environment
# 0                channel
# ...

# %%
#       max_ma  min_ma            genus         lng        lat    lithology1  \
# 0       83.5    70.6      Gorgosaurus -111.528732  50.740726     sandstone
# 1       83.5    70.6      Gorgosaurus -111.549347  50.737015     sandstone
# 2       83.5    70.6      Gorgosaurus -111.564636  50.723866     sandstone
# 3       83.5    70.6      Gorgosaurus -111.525337  50.740471  not reported
# 4       83.5    70.6      Gorgosaurus -111.601021  50.786999     sandstone
# ...      ...     ...              ...         ...        ...           ...
# 4780   237.0   201.3        Grallator -109.569000  38.602001  not reported
# 4781    83.5    70.6    Panoplosaurus -111.564636  50.723866  not reported
# 4783    83.5    70.6  Richardoestesia -108.320999  36.507999  not reported
# 4788    83.5    70.6  Richardoestesia -108.320602  36.508499     sandstone
# 4790    83.5    70.6    Tyrannosaurus -108.320999  36.507999  not reported
#
#              environment  THY0orTHE1
# ...

# %% [markdown]
# Environment column clean up:

# %%
# Remove parentheses and texts within
clean_df['environment'] = [re.sub(r'\(.*?\)', '', s) \
                     for s in clean_df['environment']]
# Remove forward slash and text thereafter

clean_df['environment'] = [re.sub(r'\/.*', '', s) \
                     for s in clean_df['environment']]

# Remove needless text
clean_df['environment'] = [s.replace('indet.', '') \
                     for s in clean_df['environment']]

clean_df['environment'] = [s.replace(' - large', '') \
                     for s in clean_df['environment']]

clean_df['environment'] = [s.replace(' - small', '') \
                     for s in clean_df['environment']]

# Remove empty spaces after text
clean_df['environment'] = [re.sub(r'\s+$', '', s) \
                     for s in clean_df['environment']]

# Combine lacustrine categories
clean_df['environment'] = [re.sub(r'lacustrine deltaic', 'lacustrine delta plain', s) \
                     for s in clean_df['environment']]

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
clean_df['lithology1'] = le.fit_transform(clean_df.lithology1.values)

# %%
le = preprocessing.LabelEncoder()
clean_df['environment'] = le.fit_transform(clean_df.environment.values)

# %%
clean_df
# Out:
#       max_ma  min_ma            genus         lng        lat  lithology1  \
# 0       83.5    70.6      Gorgosaurus -111.528732  50.740726          18
# 1       83.5    70.6      Gorgosaurus -111.549347  50.737015          18
# 2       83.5    70.6      Gorgosaurus -111.564636  50.723866          18
# 3       83.5    70.6      Gorgosaurus -111.525337  50.740471          16
# 4       83.5    70.6      Gorgosaurus -111.601021  50.786999          18
# ...      ...     ...              ...         ...        ...         ...
# 4780   237.0   201.3        Grallator -109.569000  38.602001          16
# 4781    83.5    70.6    Panoplosaurus -111.564636  50.723866          16
# 4783    83.5    70.6  Richardoestesia -108.320999  36.507999          16
# 4788    83.5    70.6  Richardoestesia -108.320602  36.508499          18
# 4790    83.5    70.6    Tyrannosaurus -108.320999  36.507999          16
#
#       environment  THY0orTHE1  environmentt
# 0               3           1             3
# ...

# %%
clean_value_counts = clean_df['lithology1'].value_counts()
print(clean_value_counts)
# Out:
# 18    1570
# 16     833
# 20     250
# 15     161
# 21     136
# 4      128
# 12     124
# 19      71
# 5       46
# 22      27
# 13      18
# 6        8
# 2        7
# 1        4
# 11       4
# 23       2
# 0        2
# 7        1
# 10       1
# 9        1
# 3        1
# 8        1
# 14       1
# 17       1
# Name: lithology1, dtype: int64

# %%
clean_value_counts_geo = clean_df['environment'].value_counts()
print(clean_value_counts)

# %%
# Create a new excel file in the directory with the cleaned DataFrame
clean_df.to_excel('Starting_Data/cleaned_data.xlsx', index=False)
